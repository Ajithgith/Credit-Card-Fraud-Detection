# %%
# !pip install imbalanced-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
credit_data = pd.read_csv('/content/creditcard.csv')
credit_data.shape
# Out:
# (284807, 31)

# %%
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_data.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
correlation = credit_data.corr()
plt.figure(figsize = (30,10))
sns.heatmap(correlation, annot=True, cmap='crest')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (14,8))
sns.scatterplot(data=credit_data, x='V20', y='Amount')
# Out:
# <Axes: xlabel='V20', ylabel='Amount'>

# %%
plt.figure(figsize = (14,8))
sns.scatterplot(data=credit_data, x='V7', y='Amount')
# Out:
# <Axes: xlabel='V7', ylabel='Amount'>

# %% [markdown]
# From above 2 observations, the features 'V7' and 'V20' are slight positive corrlated to the feature, 'Amount'

# %%
plt.figure(figsize = (14,8))
sns.scatterplot(data=credit_data, x='Time', y='Amount')
# Out:
# <Axes: xlabel='Time', ylabel='Amount'>

# %%
credit_data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
credit_data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
X = credit_data.drop(['Class'], axis=1)
Y = credit_data['Class']

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
def find_outliers(data):
  for col in data.columns:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3-Q1

    upper_limit = Q3+1.5*IQR
    lower_limit = Q1-1.5*IQR

    count_outliers_upper_limit = data[data[col]>upper_limit].shape[0]
    count_outliers_lower_limit = data[data[col]<lower_limit].shape[0]

    total_outliers = count_outliers_upper_limit+count_outliers_lower_limit

    print(f'{col}:\n')

    print("Upper Limit:", upper_limit)
    print("Lower Limit:", lower_limit)
    print("Upper Limit Outliers:", count_outliers_upper_limit)
    print("Lower Limit Outliers:", count_outliers_lower_limit)
    print(f'{total_outliers} outliers out of {data.shape[0]}. i.e.; {total_outliers/data.shape[0]*100} % of outliers\n\n')

# %%
find_outliers(X)
# Out:
# Time:
#
# Upper Limit: 266999.0
# Lower Limit: -73477.0
# Upper Limit Outliers: 0
# Lower Limit Outliers: 0
# 0 outliers out of 284807. i.e.; 0.0 % of outliers
#
#
# V1:
#
# Upper Limit: 4.669664311280146
# Lower Limit: -4.274396001792603
# Upper Limit Outliers: 0
# Lower Limit Outliers: 7062
# 7062 outliers out of 284807. i.e.; 2.4795738868777804 % of outliers
#
#
# V2:
#
# Upper Limit: 2.90713454829761
# Lower Limit: -2.7019605905224315
# Upper Limit Outliers: 5096
# Lower Limit Outliers: 8430
# 13526 outliers out of 284807. i.e.; 4.7491810243428 % of outliers
#
#
# V3:
#
# Upper Limit: 3.9035361133965982
# Lower Limit: -3.7667054090861836
# Upper Limit Outliers: 20
# Lower Limit Outliers: 3343
# 3363 outliers out of 284807. i.e.; 1.1807996292225964 % of outliers
#
#
# V4:
#
# Upper Limit: 3.1313133981683787
# Lower Limit: -3.236612225031064
# Upper Limit Outliers: 8905
# Lower Limit Outliers: 2243
# 11148 outliers out of 284807. i.e.; 3.9142296362097846 % of outliers
#
#
# V5:
#
# ...

# %%
def distribution_of_columns(col):
    print(f'{col}:\n')
    sns.distplot(X[col])
    print('\n')

# %%
def replace_outliers(data):
  for col in data.columns:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3-Q1

    upper_limit = Q3+1.5*IQR
    lower_limit = Q1-1.5*IQR

    data.loc[data[col]<lower_limit, col] = lower_limit
    data.loc[data[col]>upper_limit, col] = upper_limit

  return data

# %%
replace_outliers(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0            0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1            0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2            1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3            1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4            2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  172786.0 -7.628419  5.010545 -6.643046 -2.066656 -4.602168 -2.606837
# 284803  172787.0 -0.732789 -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804  172788.0  1.919565 -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  172788.0 -0.240440  0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  172792.0 -0.533413 -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
# ...

# %%
find_outliers(X)
# Out:
# Time:
#
# Upper Limit: 266999.0
# Lower Limit: -73477.0
# Upper Limit Outliers: 0
# Lower Limit Outliers: 0
# 0 outliers out of 284807. i.e.; 0.0 % of outliers
#
#
# V1:
#
# Upper Limit: 4.669664311280146
# Lower Limit: -4.274396001792603
# Upper Limit Outliers: 0
# Lower Limit Outliers: 7062
# 7062 outliers out of 284807. i.e.; 2.4795738868777804 % of outliers
#
#
# V2:
#
# Upper Limit: 2.90713454829761
# Lower Limit: -2.7019605905224315
# Upper Limit Outliers: 5096
# Lower Limit Outliers: 8430
# 13526 outliers out of 284807. i.e.; 4.7491810243428 % of outliers
#
#
# V3:
#
# Upper Limit: 3.9035361133965982
# Lower Limit: -3.7667054090861836
# Upper Limit Outliers: 20
# Lower Limit Outliers: 3343
# 3363 outliers out of 284807. i.e.; 1.1807996292225964 % of outliers
#
#
# V4:
#
# Upper Limit: 3.1313133981683787
# Lower Limit: -3.236612225031064
# Upper Limit Outliers: 8905
# Lower Limit Outliers: 2243
# 11148 outliers out of 284807. i.e.; 3.9142296362097846 % of outliers
#
#
# V5:
#
# ...

# %% [markdown]
# Handled the outliers in all the numerical features.

# %%
X.shape, Y.shape

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

# %%
10.0 **np.arange(-2,3)

# %%
log_class = LogisticRegression()
grid = {'C': 10.0 **np.arange(-2,3), 'penalty':['l1', 'l2']}
cv = KFold(n_splits=5, shuffle=False, random_state=None)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
clf = GridSearchCV(log_class, grid, cv=cv, n_jobs=-1, scoring='f1_macro')
clf.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
# ...

# %%
Y_pred = clf.predict(X_test)
print(confusion_matrix(Y_test, Y_pred))
print(accuracy_score(Y_test, Y_pred))
print(classification_report(Y_test, Y_pred))
# Out:
# [[85266    31]
#  [   42   104]]
# 0.9991456292499094
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85297
#            1       0.77      0.71      0.74       146
#
#     accuracy                           1.00     85443
#    macro avg       0.88      0.86      0.87     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=10, criterion='gini', random_state=None)
classifier.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
Y_pred = classifier.predict(X_test)
print(confusion_matrix(Y_test, Y_pred))
print(accuracy_score(Y_test, Y_pred))
print(classification_report(Y_test, Y_pred))
# Out:
# [[85290     7]
#  [   30   116]]
# 0.9995669627705019
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85297
#            1       0.94      0.79      0.86       146
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.90      0.93     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
from collections import Counter
from imblearn.over_sampling import RandomOverSampler

os = RandomOverSampler()
X_train_os, Y_train_os = os.fit_resample(X_train, Y_train)
print("The number of classes before fit {}".format(Counter(Y_train)))
print("The number of classes after fit {}".format(Counter(Y_train_os)))
# Out:
# The number of classes before fit Counter({0: 199018, 1: 346})
# The number of classes after fit Counter({0: 199018, 1: 199018})

# %%
cla = RandomForestClassifier(n_estimators=10, criterion='gini', random_state=None)
cla.fit(X_train_os, Y_train_os)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
Y_pred = cla.predict(X_test)
print(confusion_matrix(Y_test, Y_pred))
print(accuracy_score(Y_test, Y_pred))
print(classification_report(Y_test, Y_pred))
# Out:
# [[85289     8]
#  [   25   121]]
# 0.9996137776061234
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85297
#            1       0.94      0.83      0.88       146
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.91      0.94     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
from imblearn.combine import SMOTETomek

sm = SMOTETomek()
X_train_sm, Y_train_sm = sm.fit_resample(X_train, Y_train)
print("The number of classes before fit {}".format(Counter(Y_train)))
print("The number of classes after fit {}".format(Counter(Y_train_sm)))
# Out:
# The number of classes before fit Counter({0: 199018, 1: 346})
# The number of classes after fit Counter({0: 197919, 1: 197919})

# %%
clp = RandomForestClassifier(n_estimators=10, criterion='gini', random_state=None)
clp.fit(X_train_sm, Y_train_sm)

# %%
Y_pred = clp.predict(X_test)
print(confusion_matrix(Y_test, Y_pred))
print(accuracy_score(Y_test, Y_pred))
print(classification_report(Y_test, Y_pred))
